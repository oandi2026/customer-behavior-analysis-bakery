# %%
document/customer_survey.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 document/customer_survey.csv
#
# NameError: name 'document' is not defined

# %%
document
